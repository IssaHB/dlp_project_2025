# %% [markdown]
# # Model IV Galaxy Classifier Improved (Spiral, Elliptical, Odd objects)
#
# **Most of this code is made by the authors of the paper of Ghaderi et al. (2025) (https://iopscience.iop.org/article/10.3847/1538-4365/ada8ab) and taken from the GitHub Repository: https://github.com/hmddev1/machine_learning_for_morphological_galaxy_classification**
#
# **This notebook classifies the images of galaxies to spiral and elliptical galaxies and odd objects using the Vision Transformer and ResNet50 (Model IV).**
#
# **Purpose of this notebook: Improve Model IV using seeding and cross-validation**

# %%
import os
path = '/content/drive/Shared drives/DLP Project/Project/Models/Galaxy Models/Looping each Model'
os.chdir(path)
# %run imports.py
# %matplotlib inline
import plotting
roc_curves = {}

# Paths to images
spath = r'/content/drive/Shared drives/DLP Project/Project/Data/galaxy/images/cropped_spiral'
epath = r'/content/drive/Shared drives/DLP Project/Project/Data/galaxy/images/cropped_elliptical'
opath = r'/content/drive/Shared drives/DLP Project/Project/Data/galaxy/images/cropped_odd'

# Default image size and zernike order.
image_size = 200
zernike_order = 45

# Loading the ZMs and concatenating to a consolidated dataset
spiral_data = pd.read_csv('/content/drive/Shared drives/DLP Project/Project/spiral_zms.csv')
elliptical_data = pd.read_csv('/content/drive/Shared drives/DLP Project/Project/elliptical_zms.csv')
odd_data = pd.read_csv('/content/drive/Shared drives/DLP Project/Project/odd_zms.csv')

spiral_data.drop("Unnamed: 0", axis = 1, inplace = True)
elliptical_data.drop("Unnamed: 0", axis = 1, inplace = True)
odd_data.drop("Unnamed: 0", axis = 1, inplace = True)

all_zm_data = np.concatenate([spiral_data, elliptical_data, odd_data])
np.shape(all_zm_data)

spiral_label = [0] * len(spiral_data)
elliptical_label = [1] * len(elliptical_data)
odd_label = [2] * len(odd_data)

all_labels = spiral_label + elliptical_label + odd_label
len(all_labels)
# Out:
# 11744

# %%
def load_galaxy_images(data_dir, target_size):
        """
        Loads, resizes, and processes all JPG images from the specified directory.

        Parameters:
        data_dir (str): The directory containing the JPG images to be processed.
        target_size (tuple): The target size for resizing the images, specified as (width, height).

        Returns:
        list: A list of PIL Image objects, each representing a resized and processed image.

        The function performs the following steps:
        1. Lists all JPG image files in the specified directory.
        2. Reads each image using OpenCV.
        3. Resizes each image to the specified target size.
        4. Scales the pixel values and converts the image to a format compatible with PIL.
        5. Converts each resized image to a PIL Image object.
        6. Appends each PIL Image object to a list.
        7. Returns the list of PIL Image objects.
        """

        all_images = []

        file_path = [os.path.join(data_dir, filename) for filename in os.listdir(data_dir) if filename.endswith('.jpg')]

        for img in file_path:
            image = cv2.imread(img)
            resized_images=cv2.resize(image, target_size)
            resized_images = (resized_images * 255).astype(np.uint8)
            pil_images = Image.fromarray(resized_images)
            all_images.append(pil_images)

        return all_images

sp_dir = '/content/drive/Shared drives/DLP Project/Project/Data/galaxy/images/cropped_spiral'
el_dir = '/content/drive/Shared drives/DLP Project/Project/Data/galaxy/images/cropped_elliptical'
odd_dir = '/content/drive/Shared drives/DLP Project/Project/Data/galaxy/images/cropped_odd'

image_size = 200

sp_img = load_galaxy_images(sp_dir, target_size=(image_size,image_size))
el_img = load_galaxy_images(el_dir, target_size=(image_size,image_size))
odd_img = load_galaxy_images(odd_dir, target_size=(image_size,image_size))

# Due to lack of computational power, we will use a subset of the data (6000 galaxies) while keeping the same ratios between categories.
sp_img = sp_img[:3136]
el_img = el_img[:2082]
odd_img = odd_img[:782]

all_data = sp_img + el_img + odd_img

# Labels
label_s = [0] * len(sp_img)
label_e = [1] * len(el_img)
label_o = [2] * len(odd_img)

all_labels = label_s + label_e + label_o
len(all_labels)


# transforms for training data
train_transform = transforms.Compose([transforms.CenterCrop(image_size),
                                      transforms.RandomRotation(90),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.RandomVerticalFlip(),
                                      transforms.RandomResizedCrop(image_size, scale=(0.8, 1.0), ratio=(0.99, 1.01)),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                      ])


# transforms for test data
test_transform = transforms.Compose([transforms.CenterCrop(image_size),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                      ])

# %%
# Set a fixed seed for reproducibility
seed_value = 42
np.random.seed(seed_value)
random.seed(seed_value)
tf.random.set_seed(seed_value)

metrics_list = []

# Cross Validation Setup using StratifiedKFold
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)

for fold, (train_idx, test_idx) in enumerate(skf.split(all_data, all_labels)):
    print(f"Fold {fold + 1}...")

    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(all_data, all_labels, np.arange(len(all_labels)), test_size=0.25, shuffle=True, random_state=None)
    y_train_encoded = to_categorical(y_train, num_classes=3)

    # Transformer for training data
    transformed_X_train = []
    for i in range(len(X_train)):
        transformed_train_images = train_transform(X_train[i])
        new_image = np.transpose(transformed_train_images, (1, 2, 0))
        transformed_X_train.append(new_image)

    # Transformer for testing data
    transformed_X_test = []
    for j in range(len(X_test)):
        transformed_test_images = test_transform(X_test[j])
        new_images = np.transpose(transformed_test_images, (1, 2, 0))
        transformed_X_test.append(new_images)

    class_weights = {0: len(all_data) / (3 * len(spiral_data)),
                     1: len(all_data) / (3 * len(elliptical_data)),
                     2: len(all_data) / (3 * len(odd_data))}

    # Defining the pretrained ResNet50
    b_size = 64
    e_num = 30

    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))

    x = Flatten()(base_model.output)
    x = Dense(64, activation='relu')(x)  # The custom layers
    output = Dense(3, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=output)

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

    history = model.fit(
    np.array(transformed_X_train), y_train_encoded,
    batch_size=b_size,
    epochs=e_num,
    verbose = 1,
    callbacks=es,
    class_weight=class_weights,
    validation_split=0.1)

    y_pred = model.predict(np.array(transformed_X_test))
    y_pred_labels = np.argmax(y_pred, axis=1)

    # Compute confusion matrix
    cm = confusion_matrix(y_test, y_pred_labels)

    # Performance metrics (per-class)
    recall_per_class = recall_score(y_test, y_pred_labels, average=None)
    precision_per_class = precision_score(y_test, y_pred_labels, average=None)
    f1_per_class = f1_score(y_test, y_pred_labels, average=None)
    accuracy = accuracy_score(y_test, y_pred_labels) # overall

    tss_per_class = {}
    for i, class_name in enumerate(['Spiral', 'Elliptical', 'Odd']):
        tp = cm[i, i]
        fn = np.sum(cm[i, :]) - tp
        fp = np.sum(cm[:, i]) - tp
        tn = np.sum(cm) - (tp + fn + fp)
        tss_per_class[class_name] = (tp / (tp + fn + 1e-6)) - (fp / (fp + tn + 1e-6))

    metrics_list.append({
        'Fold': fold + 1,
        'Recall per Class': recall_per_class,
        'Precision per Class': precision_per_class,
        'F1 per Class': f1_per_class,
        'Accuracy': accuracy,
        'TSS per Class': tss_per_class
    })

for result in metrics_list:
    print(result)
# Out:
# Fold 1...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Epoch 1/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 102s 693ms/step - accuracy: 0.4862 - loss: 5.1528 - val_accuracy: 0.1600 - val_loss: 11.9960
# Epoch 2/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.4883 - loss: 0.7710 - val_accuracy: 0.2778 - val_loss: 1.0920
# Epoch 3/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.8500 - loss: 0.4641 - val_accuracy: 0.5044 - val_loss: 1.0808
# Epoch 4/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8173 - loss: 0.5284 - val_accuracy: 0.3289 - val_loss: 13.4202
# Epoch 5/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9046 - loss: 0.3545 - val_accuracy: 0.5022 - val_loss: 1.1738
# Epoch 6/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9076 - loss: 0.3201 - val_accuracy: 0.3200 - val_loss: 1.6079
# Epoch 7/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8622 - loss: 0.4939 - val_accuracy: 0.3289 - val_loss: 1.1023
# Epoch 8/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8081 - loss: 0.5367 - val_accuracy: 0.3311 - val_loss: 1.1602
# Epoch 9/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.8880 - loss: 0.4052 - val_accuracy: 0.3667 - val_loss: 1.0803
# Epoch 10/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9155 - loss: 0.2730 - val_accuracy: 0.5178 - val_loss: 2.8281
# Epoch 11/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8961 - loss: 0.2535 - val_accuracy: 0.7378 - val_loss: 1.3540
# Epoch 12/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9277 - loss: 0.2208 - val_accuracy: 0.2733 - val_loss: 2.7530
# Epoch 13/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.8968 - loss: 0.2124 - val_accuracy: 0.8067 - val_loss: 0.6042
# Epoch 14/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9344 - loss: 0.2123 - val_accuracy: 0.4889 - val_loss: 1.5901
# Epoch 15/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9472 - loss: 0.1528 - val_accuracy: 0.8289 - val_loss: 0.6850
# Epoch 16/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9757 - loss: 0.0860 - val_accuracy: 0.8933 - val_loss: 0.4383
# Epoch 17/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9798 - loss: 0.0640 - val_accuracy: 0.9133 - val_loss: 0.3786
# Epoch 18/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9805 - loss: 0.0659 - val_accuracy: 0.8044 - val_loss: 0.8133
# Epoch 19/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9817 - loss: 0.0557 - val_accuracy: 0.7156 - val_loss: 2.3982
# Epoch 20/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9745 - loss: 0.0735 - val_accuracy: 0.8956 - val_loss: 0.5187
# Epoch 21/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9870 - loss: 0.0343 - val_accuracy: 0.9111 - val_loss: 0.5642
# Epoch 22/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9928 - loss: 0.0317 - val_accuracy: 0.8844 - val_loss: 0.5945
# Epoch 23/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9939 - loss: 0.0201 - val_accuracy: 0.9044 - val_loss: 0.5036
# Epoch 24/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9969 - loss: 0.0096 - val_accuracy: 0.9067 - val_loss: 0.6150
# Epoch 25/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9986 - loss: 0.0050 - val_accuracy: 0.9089 - val_loss: 0.6065
# Epoch 26/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9983 - loss: 0.0039 - val_accuracy: 0.9044 - val_loss: 0.6031
# Epoch 27/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9986 - loss: 0.0037 - val_accuracy: 0.9089 - val_loss: 0.7247
# Epoch 27: early stopping
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step
# Fold 2...
# Epoch 1/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 82s 575ms/step - accuracy: 0.6131 - loss: 4.7466 - val_accuracy: 0.1533 - val_loss: 1.1006
# Epoch 2/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.8018 - loss: 0.5052 - val_accuracy: 0.1533 - val_loss: 1.1012
# Epoch 3/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8483 - loss: 0.3681 - val_accuracy: 0.2467 - val_loss: 1.1367
# Epoch 4/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8774 - loss: 0.4300 - val_accuracy: 0.2378 - val_loss: 1.1000
# Epoch 5/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8516 - loss: 0.4000 - val_accuracy: 0.1578 - val_loss: 1.1185
# Epoch 6/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9085 - loss: 0.2428 - val_accuracy: 0.1956 - val_loss: 1.1093
# Epoch 7/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9414 - loss: 0.2014 - val_accuracy: 0.3933 - val_loss: 1.0512
# Epoch 8/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9436 - loss: 0.1539 - val_accuracy: 0.5511 - val_loss: 1.0063
# Epoch 9/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9587 - loss: 0.1040 - val_accuracy: 0.6911 - val_loss: 0.9214
# Epoch 10/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9695 - loss: 0.0734 - val_accuracy: 0.8444 - val_loss: 0.3725
# Epoch 11/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9821 - loss: 0.0506 - val_accuracy: 0.8289 - val_loss: 0.5762
# Epoch 12/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9780 - loss: 0.0447 - val_accuracy: 0.8778 - val_loss: 0.3801
# Epoch 13/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9845 - loss: 0.0430 - val_accuracy: 0.9356 - val_loss: 0.2221
# Epoch 14/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9889 - loss: 0.0316 - val_accuracy: 0.8933 - val_loss: 0.3063
# Epoch 15/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9890 - loss: 0.0307 - val_accuracy: 0.9133 - val_loss: 0.3138
# Epoch 16/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9901 - loss: 0.0262 - val_accuracy: 0.9289 - val_loss: 0.3837
# Epoch 17/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9977 - loss: 0.0062 - val_accuracy: 0.9289 - val_loss: 0.3192
# Epoch 18/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9976 - loss: 0.0047 - val_accuracy: 0.9356 - val_loss: 0.3466
# Epoch 19/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9983 - loss: 0.0048 - val_accuracy: 0.9333 - val_loss: 0.3476
# Epoch 20/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 1.0000 - loss: 7.8126e-04 - val_accuracy: 0.9422 - val_loss: 0.3002
# Epoch 21/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 1.0000 - loss: 2.1717e-04 - val_accuracy: 0.9444 - val_loss: 0.3078
# Epoch 22/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 1.0000 - loss: 1.5624e-04 - val_accuracy: 0.9422 - val_loss: 0.3102
# Epoch 23/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 1.0000 - loss: 1.2711e-04 - val_accuracy: 0.9422 - val_loss: 0.3127
# Epoch 23: early stopping
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step
# Fold 3...
# Epoch 1/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 82s 574ms/step - accuracy: 0.5537 - loss: 8.6476 - val_accuracy: 0.3200 - val_loss: 1.1059
# Epoch 2/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8449 - loss: 0.7288 - val_accuracy: 0.3200 - val_loss: 1.1122
# Epoch 3/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9001 - loss: 0.5649 - val_accuracy: 0.2489 - val_loss: 1.1258
# Epoch 4/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9106 - loss: 0.5179 - val_accuracy: 0.3422 - val_loss: 1.1143
# Epoch 5/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9260 - loss: 0.4542 - val_accuracy: 0.3200 - val_loss: 1.1253
# Epoch 6/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9161 - loss: 0.5655 - val_accuracy: 0.3200 - val_loss: 1.1493
# Epoch 7/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.7770 - loss: 0.7397 - val_accuracy: 0.3200 - val_loss: 1.1524
# Epoch 8/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8180 - loss: 0.5281 - val_accuracy: 0.4889 - val_loss: 1.8392
# Epoch 9/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9009 - loss: 0.3439 - val_accuracy: 0.4578 - val_loss: 6.9166
# Epoch 10/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8930 - loss: 0.3159 - val_accuracy: 0.3267 - val_loss: 1.1554
# Epoch 11/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9257 - loss: 0.2037 - val_accuracy: 0.6800 - val_loss: 0.8774
# Epoch 12/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8886 - loss: 0.4367 - val_accuracy: 0.3822 - val_loss: 1.1798
# Epoch 13/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8558 - loss: 0.3250 - val_accuracy: 0.5556 - val_loss: 1.2305
# Epoch 14/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.8966 - loss: 0.2378 - val_accuracy: 0.8533 - val_loss: 0.3901
# Epoch 15/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8971 - loss: 0.2717 - val_accuracy: 0.5156 - val_loss: 2.4053
# Epoch 16/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8778 - loss: 0.3288 - val_accuracy: 0.3200 - val_loss: 1.1585
# Epoch 17/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8893 - loss: 0.2673 - val_accuracy: 0.7689 - val_loss: 0.6654
# Epoch 18/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9189 - loss: 0.1627 - val_accuracy: 0.7089 - val_loss: 1.3018
# Epoch 19/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9312 - loss: 0.1510 - val_accuracy: 0.6844 - val_loss: 1.1176
# Epoch 20/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9370 - loss: 0.1599 - val_accuracy: 0.7867 - val_loss: 0.9694
# Epoch 21/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9609 - loss: 0.1111 - val_accuracy: 0.8222 - val_loss: 0.8827
# Epoch 22/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9775 - loss: 0.0521 - val_accuracy: 0.9022 - val_loss: 0.3866
# Epoch 23/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9921 - loss: 0.0183 - val_accuracy: 0.9178 - val_loss: 0.3181
# Epoch 24/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9987 - loss: 0.0048 - val_accuracy: 0.9222 - val_loss: 0.3167
# Epoch 25/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9991 - loss: 0.0038 - val_accuracy: 0.9156 - val_loss: 0.3273
# Epoch 26/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9987 - loss: 0.0028 - val_accuracy: 0.9333 - val_loss: 0.3405
# Epoch 27/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9991 - loss: 0.0021 - val_accuracy: 0.9311 - val_loss: 0.3556
# Epoch 28/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9991 - loss: 0.0019 - val_accuracy: 0.9311 - val_loss: 0.3586
# Epoch 29/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9991 - loss: 0.0018 - val_accuracy: 0.9311 - val_loss: 0.3645
# Epoch 30/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9991 - loss: 0.0017 - val_accuracy: 0.9311 - val_loss: 0.3692
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step
# Fold 4...
# Epoch 1/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 82s 574ms/step - accuracy: 0.4951 - loss: 8.7427 - val_accuracy: 0.3422 - val_loss: 1.1542
# Epoch 2/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.7954 - loss: 0.5380 - val_accuracy: 0.3422 - val_loss: 1.1539
# Epoch 3/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8763 - loss: 0.3320 - val_accuracy: 0.1400 - val_loss: 1.4388
# Epoch 4/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9270 - loss: 0.2086 - val_accuracy: 0.1400 - val_loss: 1.6811
# Epoch 5/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9354 - loss: 0.1944 - val_accuracy: 0.1400 - val_loss: 2.1256
# Epoch 6/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9525 - loss: 0.1365 - val_accuracy: 0.1400 - val_loss: 2.7110
# Epoch 7/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9694 - loss: 0.0943 - val_accuracy: 0.1400 - val_loss: 3.3199
# Epoch 8/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9746 - loss: 0.0740 - val_accuracy: 0.1489 - val_loss: 1.9568
# Epoch 9/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9839 - loss: 0.0496 - val_accuracy: 0.4044 - val_loss: 1.1242
# Epoch 10/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9786 - loss: 0.0571 - val_accuracy: 0.2422 - val_loss: 8.7582
# Epoch 11/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9573 - loss: 0.1325 - val_accuracy: 0.8733 - val_loss: 0.9235
# Epoch 12/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9662 - loss: 0.1321 - val_accuracy: 0.8578 - val_loss: 0.4324
# Epoch 13/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9496 - loss: 0.1882 - val_accuracy: 0.6422 - val_loss: 43.6858
# Epoch 14/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 253ms/step - accuracy: 0.9066 - loss: 0.3111 - val_accuracy: 0.5178 - val_loss: 1.1801
# Epoch 15/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9107 - loss: 0.2607 - val_accuracy: 0.7822 - val_loss: 0.7079
# Epoch 16/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9479 - loss: 0.1330 - val_accuracy: 0.6089 - val_loss: 3.0451
# Epoch 17/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9693 - loss: 0.0933 - val_accuracy: 0.9222 - val_loss: 0.3593
# Epoch 18/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9828 - loss: 0.0704 - val_accuracy: 0.9222 - val_loss: 0.2838
# Epoch 19/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9895 - loss: 0.0405 - val_accuracy: 0.9222 - val_loss: 0.2253
# Epoch 20/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9967 - loss: 0.0105 - val_accuracy: 0.9289 - val_loss: 0.2661
# Epoch 21/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9998 - loss: 0.0032 - val_accuracy: 0.9400 - val_loss: 0.2437
# Epoch 22/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.9311 - val_loss: 0.2861
# Epoch 23/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 0.9986 - loss: 0.0061 - val_accuracy: 0.9267 - val_loss: 0.4123
# Epoch 24/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9952 - loss: 0.0119 - val_accuracy: 0.9222 - val_loss: 0.3037
# Epoch 25/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9980 - loss: 0.0035 - val_accuracy: 0.9022 - val_loss: 0.4078
# Epoch 26/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9997 - loss: 0.0021 - val_accuracy: 0.9311 - val_loss: 0.3113
# Epoch 27/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 1.0000 - loss: 3.7517e-04 - val_accuracy: 0.9289 - val_loss: 0.3208
# Epoch 28/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 1.0000 - loss: 1.3733e-04 - val_accuracy: 0.9333 - val_loss: 0.3272
# Epoch 29/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 1.0000 - loss: 1.1052e-04 - val_accuracy: 0.9333 - val_loss: 0.3322
# Epoch 29: early stopping
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 94ms/step
# Fold 5...
# Epoch 1/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 82s 577ms/step - accuracy: 0.5668 - loss: 6.9974 - val_accuracy: 0.1400 - val_loss: 1.2752
# Epoch 2/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.8221 - loss: 0.4973 - val_accuracy: 0.1400 - val_loss: 1.3843
# Epoch 3/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8519 - loss: 0.4213 - val_accuracy: 0.3444 - val_loss: 202.2935
# Epoch 4/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8823 - loss: 0.5701 - val_accuracy: 0.1400 - val_loss: 1.1199
# Epoch 5/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9152 - loss: 0.2698 - val_accuracy: 0.1467 - val_loss: 1.1265
# Epoch 6/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9172 - loss: 0.3063 - val_accuracy: 0.2956 - val_loss: 1.1232
# Epoch 7/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9337 - loss: 0.2391 - val_accuracy: 0.3578 - val_loss: 1.2676
# Epoch 8/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8962 - loss: 0.2582 - val_accuracy: 0.4333 - val_loss: 1.0889
# Epoch 9/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9437 - loss: 0.1752 - val_accuracy: 0.4933 - val_loss: 1.0922
# Epoch 10/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9177 - loss: 0.1712 - val_accuracy: 0.3911 - val_loss: 1.1851
# Epoch 11/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9442 - loss: 0.1332 - val_accuracy: 0.5333 - val_loss: 0.9650
# Epoch 12/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.8849 - loss: 0.3641 - val_accuracy: 0.3511 - val_loss: 1.1118
# Epoch 13/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8991 - loss: 0.3053 - val_accuracy: 0.5289 - val_loss: 1.5501
# Epoch 14/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 0.8832 - loss: 0.4086 - val_accuracy: 0.7044 - val_loss: 0.6049
# Epoch 15/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9079 - loss: 0.2326 - val_accuracy: 0.5289 - val_loss: 3.9351
# Epoch 16/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9289 - loss: 0.1550 - val_accuracy: 0.8711 - val_loss: 0.4124
# Epoch 17/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9512 - loss: 0.1149 - val_accuracy: 0.8644 - val_loss: 13.0335
# Epoch 18/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9557 - loss: 0.1413 - val_accuracy: 0.9022 - val_loss: 0.3265
# Epoch 19/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9453 - loss: 0.1867 - val_accuracy: 0.1822 - val_loss: 6.8868
# Epoch 20/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9041 - loss: 0.2036 - val_accuracy: 0.7867 - val_loss: 0.6401
# Epoch 21/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9527 - loss: 0.1075 - val_accuracy: 0.9289 - val_loss: 0.2632
# Epoch 22/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9612 - loss: 0.0936 - val_accuracy: 0.3533 - val_loss: 3.6335
# Epoch 23/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8844 - loss: 0.3958 - val_accuracy: 0.3556 - val_loss: 1.1230
# Epoch 24/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.8642 - loss: 0.4009 - val_accuracy: 0.3444 - val_loss: 1.1172
# Epoch 25/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.8966 - loss: 0.2927 - val_accuracy: 0.3889 - val_loss: 2.2991
# Epoch 26/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9177 - loss: 0.2248 - val_accuracy: 0.7156 - val_loss: 1.5198
# Epoch 27/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9237 - loss: 0.2001 - val_accuracy: 0.7467 - val_loss: 0.8899
# Epoch 28/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 254ms/step - accuracy: 0.9272 - loss: 0.1506 - val_accuracy: 0.7022 - val_loss: 1.5619
# Epoch 29/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9501 - loss: 0.1117 - val_accuracy: 0.9222 - val_loss: 0.2812
# Epoch 30/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9540 - loss: 0.0966 - val_accuracy: 0.8844 - val_loss: 0.3887
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step
# {'Fold': 1, 'Recall per Class': array([0.97404203, 0.96653543, 0.6284153 ]), 'Precision per Class': array([0.90993072, 0.99191919, 0.82733813]), 'F1 per Class': array([0.94089552, 0.97906281, 0.71428571]), 'Accuracy': 0.9293333333333333, 'TSS per Class': {'Spiral': 0.8611621419276568, 'Elliptical': 0.962503173107786, 'Odd': 0.6101920625021758}}
# {'Fold': 2, 'Recall per Class': array([0.97845374, 0.99227799, 0.68393782]), 'Precision per Class': array([0.92677071, 0.98279159, 0.91666667]), 'F1 per Class': array([0.95191122, 0.98751201, 0.78338279]), 'Accuracy': 0.9453333333333334, 'TSS per Class': {'Spiral': 0.8926590823756528, 'Elliptical': 0.9831130209216289, 'Odd': 0.6747564890044649}}
# {'Fold': 3, 'Recall per Class': array([0.97389034, 0.98507463, 0.66666667]), 'Precision per Class': array([0.91646192, 0.98876404, 0.86842105]), 'F1 per Class': array([0.9443038 , 0.98691589, 0.75428571]), 'Accuracy': 0.9373333333333334, 'TSS per Class': {'Spiral': 0.8812472865092896, 'Elliptical': 0.9788505586442608, 'Odd': 0.6513056802085427}}
# {'Fold': 4, 'Recall per Class': array([0.9836478 , 0.99214145, 0.70918367]), 'Precision per Class': array([0.92874109, 0.99605523, 0.9205298 ]), 'F1 per Class': array([0.95540623, 0.99409449, 0.80115274]), 'Accuracy': 0.9506666666666667, 'TSS per Class': {'Spiral': 0.8985414146468405, 'Elliptical': 0.9901232884126392, 'Odd': 0.6999812158704307}}
# {'Fold': 5, 'Recall per Class': array([0.81434059, 0.96175908, 0.51530612]), 'Precision per Class': array([0.89703808, 0.77863777, 0.69655172]), 'F1 per Class': array([0.85369128, 0.86056459, 0.59237537]), 'Accuracy': 0.8266666666666667, 'TSS per Class': {'Spiral': 0.7128106854444375, 'Elliptical': 0.8153926526885303, 'Odd': 0.48156378855739923}}

# %%
# Running the same code independently, due to limited computational resources.

# Set a fixed seed for reproducibility
seed_value = 42
np.random.seed(seed_value)
random.seed(seed_value)
tf.random.set_seed(seed_value)

metrics_list = []

# Cross Validation Setup using StratifiedKFold
n_splits = 5
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed_value)

for fold, (train_idx, test_idx) in enumerate(skf.split(all_data, all_labels)):
    print(f"Fold {fold + 1}...")

    X_train, X_test, y_train, y_test, train_indices, test_indices = train_test_split(all_data, all_labels, np.arange(len(all_labels)), test_size=0.25, shuffle=True, random_state=None)
    y_train_encoded = to_categorical(y_train, num_classes=3)

    # Transformer for training data
    transformed_X_train = []
    for i in range(len(X_train)):
        transformed_train_images = train_transform(X_train[i])
        new_image = np.transpose(transformed_train_images, (1, 2, 0))
        transformed_X_train.append(new_image)

    # Transformer for testing data
    transformed_X_test = []
    for j in range(len(X_test)):
        transformed_test_images = test_transform(X_test[j])
        new_images = np.transpose(transformed_test_images, (1, 2, 0))
        transformed_X_test.append(new_images)

    class_weights = {0: len(all_data) / (3 * len(spiral_data)),
                     1: len(all_data) / (3 * len(elliptical_data)),
                     2: len(all_data) / (3 * len(odd_data))}

    # Defining the pretrained ResNet50
    b_size = 64
    e_num = 30

    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))

    x = Flatten()(base_model.output)
    x = Dense(64, activation='relu')(x)  # The custom layers
    output = Dense(3, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=output)

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

    history = model.fit(
    np.array(transformed_X_train), y_train_encoded,
    batch_size=b_size,
    epochs=e_num,
    verbose = 1,
    callbacks=es,
    class_weight=class_weights,
    validation_split=0.1)

    y_pred = model.predict(np.array(transformed_X_test))
    y_pred_labels = np.argmax(y_pred, axis=1)

    # Compute confusion matrix
    cm = confusion_matrix(y_test, y_pred_labels)

    # Performance metrics (per-class)
    recall_per_class = recall_score(y_test, y_pred_labels, average=None)
    precision_per_class = precision_score(y_test, y_pred_labels, average=None)
    f1_per_class = f1_score(y_test, y_pred_labels, average=None)
    accuracy = accuracy_score(y_test, y_pred_labels) # overall

    tss_per_class = {}
    for i, class_name in enumerate(['Spiral', 'Elliptical', 'Odd']):
        tp = cm[i, i]
        fn = np.sum(cm[i, :]) - tp
        fp = np.sum(cm[:, i]) - tp
        tn = np.sum(cm) - (tp + fn + fp)
        tss_per_class[class_name] = (tp / (tp + fn + 1e-6)) - (fp / (fp + tn + 1e-6))

    metrics_list.append({
        'Fold': fold + 1,
        'Recall per Class': recall_per_class,
        'Precision per Class': precision_per_class,
        'F1 per Class': f1_per_class,
        'Accuracy': accuracy,
        'TSS per Class': tss_per_class
    })

for result in metrics_list:
    print(result)
# Out:
# Fold 1...
# Epoch 1/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 83s 580ms/step - accuracy: 0.6253 - loss: 4.8092 - val_accuracy: 0.3289 - val_loss: 5.1448
# Epoch 2/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 0.7767 - loss: 0.5665 - val_accuracy: 0.1600 - val_loss: 6.7775
# Epoch 3/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 0.8598 - loss: 0.3761 - val_accuracy: 0.1600 - val_loss: 1.9046
# Epoch 4/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9031 - loss: 0.2974 - val_accuracy: 0.3511 - val_loss: 1.4716
# Epoch 5/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 0.9186 - loss: 0.2529 - val_accuracy: 0.1756 - val_loss: 4.9492
# Epoch 6/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9456 - loss: 0.1477 - val_accuracy: 0.1622 - val_loss: 2.0510
# Epoch 7/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9615 - loss: 0.0987 - val_accuracy: 0.1622 - val_loss: 2.9894
# Epoch 8/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9772 - loss: 0.0654 - val_accuracy: 0.2622 - val_loss: 3.3107
# Epoch 9/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 255ms/step - accuracy: 0.9750 - loss: 0.0586 - val_accuracy: 0.6556 - val_loss: 1.2819
# Epoch 10/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 0.9853 - loss: 0.0390 - val_accuracy: 0.6622 - val_loss: 0.9275
# Epoch 11/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9877 - loss: 0.0336 - val_accuracy: 0.7933 - val_loss: 0.7961
# Epoch 12/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 0.9695 - loss: 0.0680 - val_accuracy: 0.8311 - val_loss: 0.7520
# Epoch 13/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9577 - loss: 0.1279 - val_accuracy: 0.8600 - val_loss: 0.3684
# Epoch 14/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9693 - loss: 0.0999 - val_accuracy: 0.9178 - val_loss: 0.2670
# Epoch 15/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9801 - loss: 0.0461 - val_accuracy: 0.9222 - val_loss: 0.2670
# Epoch 16/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 0.9930 - loss: 0.0221 - val_accuracy: 0.8756 - val_loss: 0.4826
# Epoch 17/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9880 - loss: 0.0254 - val_accuracy: 0.9267 - val_loss: 0.4138
# Epoch 18/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 257ms/step - accuracy: 0.9918 - loss: 0.0222 - val_accuracy: 0.9111 - val_loss: 0.5713
# Epoch 19/30
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 16s 256ms/step - accuracy: 0.9964 - loss: 0.0138 - val_accuracy: 0.4644 - val_loss: 8.8692
# Epoch 20/30
# 49/64 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9507 - loss: 0.1455
